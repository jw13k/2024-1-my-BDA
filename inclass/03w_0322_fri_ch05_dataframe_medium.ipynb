# %% [markdown]
# <a href="https://colab.research.google.com/github/jw13k/2024-1-my-BDA/blob/main/inclass/03w_0322_fri_ch05_dataframe_medium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **빅데이터분석프로그래밍**

# %% [markdown]
# ##파이썬 설치확인

# %%
import site

# %%
import sys
import pandas as pd
import numpy as np

print(sys.version)
print(pd.__version__)
print(np.__version__)
# Out:
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# 1.5.3
# 1.25.2

# %%
# !pip install koreanize_matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 48.7 MB/s eta 0:00:00
# ...

# %%
#그림선명
# %config inlineBackend.figure_format = 'retina'

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.plot([-10, 5, -3, 1])
plt.title('그래프제목')
plt.xlabel('직선')
# Out:
# Text(0.5, 0, '직선')

# %% [markdown]
# ##05데이터분석기초 데이터 파악하기, 다루기 쉽게 수정하기

# %% [markdown]
# |함수|기능|
# |----|----|
# head()|앞부분 출력|
# tail()|뒷부분 출력|
# shape|행, 열 개수 출력|
# info()|변수 속성 출력|
# describe()|여약 통계량 출력|

# %%
import pandas as pd
exam = pd.read_csv('exam.csv')

# %%
exam.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
exam.tail()
# Out:
#     id  nclass  math  english  science
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       20 non-null     int64
#  1   nclass   20 non-null     int64
#  2   math     20 non-null     int64
#  3   english  20 non-null     int64
#  4   science  20 non-null     int64
# dtypes: int64(5)
# memory usage: 928.0 bytes

# %%
exam.describe(include='all') #기술(기초) 통계량
# Out:
#              id     nclass       math    english    science
# count  20.00000  20.000000  20.000000  20.000000  20.000000
# mean   10.50000   3.000000  57.450000  84.900000  59.450000
# std     5.91608   1.450953  20.299015  12.875517  25.292968
# min     1.00000   1.000000  20.000000  56.000000  12.000000
# 25%     5.75000   2.000000  45.750000  78.000000  45.000000
# 50%    10.50000   3.000000  54.000000  86.500000  62.500000
# 75%    15.25000   4.000000  75.750000  98.000000  78.000000
# max    20.00000   5.000000  90.000000  98.000000  98.000000

# %%
exam.shape
# Out:
# (20, 5)

# %% [markdown]
# ### mpg데이터 파악하기

# %%
import pandas as pd
#mpg 데이터 불러오기
mpg = pd.read_csv("mpg.csv")

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
mpg.tail()
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
mpg.describe(include="all") #요약 통계량 출력
# Out:
#        manufacturer        model       displ         year         cyl  \
# count           234          234  234.000000   234.000000  234.000000
# unique           15           38         NaN          NaN         NaN
# top           dodge  caravan 2wd         NaN          NaN         NaN
# freq             37           11         NaN          NaN         NaN
# mean            NaN          NaN    3.471795  2003.500000    5.888889
# std             NaN          NaN    1.291959     4.509646    1.611534
# min             NaN          NaN    1.600000  1999.000000    4.000000
# 25%             NaN          NaN    2.400000  1999.000000    4.000000
# 50%             NaN          NaN    3.300000  2003.500000    6.000000
# 75%             NaN          NaN    4.600000  2008.000000    8.000000
# max             NaN          NaN    7.000000  2008.000000    8.000000
#
#            trans  drv         cty         hwy   fl category
# count        234  234  234.000000  234.000000  234      234
# ...

# %%
mpg.shape
# Out:
# (234, 11)

# %%
mpg["category"]
# Out:
# 0      compact
# 1      compact
# 2      compact
# 3      compact
# 4      compact
#         ...
# 229    midsize
# 230    midsize
# 231    midsize
# 232    midsize
# 233    midsize
# Name: category, Length: 234, dtype: object

# %%
mpg[["category"]].describe()
# Out:
#        category
# count       234
# unique        7
# top         suv
# freq         62

# %%
mpg[["category", "trans",	"drv",	"cty",	"hwy",	"fl"]].describe(include="all")
# Out:
#        category     trans  drv         cty         hwy   fl
# count       234       234  234  234.000000  234.000000  234
# unique        7        10    3         NaN         NaN    5
# top         suv  auto(l4)    f         NaN         NaN    r
# freq         62        83  106         NaN         NaN  168
# mean        NaN       NaN  NaN   16.858974   23.440171  NaN
# std         NaN       NaN  NaN    4.255946    5.954643  NaN
# min         NaN       NaN  NaN    9.000000   12.000000  NaN
# 25%         NaN       NaN  NaN   14.000000   18.000000  NaN
# 50%         NaN       NaN  NaN   17.000000   24.000000  NaN
# 75%         NaN       NaN  NaN   19.000000   27.000000  NaN
# max         NaN       NaN  NaN   35.000000   44.000000  NaN

# %% [markdown]
# ## 범주형 데이터
#
# *  명목형
# *  순서형

# %%
mpg.fl.unique()
# Out:
# array(['p', 'r', 'e', 'd', 'c'], dtype=object)

# %%
mpg["fl"].unique()
# Out:
# array(['p', 'r', 'e', 'd', 'c'], dtype=object)

# %%
mpg.fl.value_counts()
# Out:
# r    168
# p     52
# e      8
# d      5
# c      1
# Name: fl, dtype: int64

# %%
mpg.trans.value_counts() #트랜스미션 출력
# Out:
# auto(l4)      83
# manual(m5)    58
# auto(l5)      39
# manual(m6)    19
# auto(s6)      16
# auto(l6)       6
# auto(av)       5
# auto(s5)       3
# auto(s4)       3
# auto(l3)       2
# Name: trans, dtype: int64

# %%
mpg.trans.value_counts()
# Out:
# auto(l4)      83
# manual(m5)    58
# auto(l5)      39
# manual(m6)    19
# auto(s6)      16
# auto(l6)       6
# auto(av)       5
# auto(s5)       3
# auto(s4)       3
# auto(l3)       2
# Name: trans, dtype: int64

# %%
mpg.trans.value_counts().sort_index()
# Out:
# auto(av)       5
# auto(l3)       2
# auto(l4)      83
# auto(l5)      39
# auto(l6)       6
# auto(s4)       3
# auto(s5)       3
# auto(s6)      16
# manual(m5)    58
# manual(m6)    19
# Name: trans, dtype: int64

# %%
mpg.hwy.value_counts() #고속ㄷ로 출력
# Out:
# 26    32
# 17    31
# 29    22
# 25    15
# 27    14
# 19    13
# 24    13
# 20    11
# 18    10
# 15    10
# 23     7
# 28     7
# 31     7
# 22     7
# 16     7
# 12     5
# 30     4
# 32     4
# 36     2
# 44     2
# 35     2
# 14     2
# 33     2
# 21     2
# 34     1
# 37     1
# 41     1
# Name: hwy, dtype: int64

# %%
mpg.category.value_counts() #카테고리 출력
# Out:
# suv           62
# compact       47
# midsize       41
# subcompact    35
# pickup        33
# minivan       11
# 2seater        5
# Name: category, dtype: int64

# %%
mpg[["category"]].value_counts() #카테고리 출력
# Out:
# category
# suv           62
# compact       47
# midsize       41
# subcompact    35
# pickup        33
# minivan       11
# 2seater        5
# dtype: int64

# %%
mpg.category.unique()
# Out:
# array(['compact', 'midsize', 'suv', '2seater', 'minivan', 'pickup',
#        'subcompact'], dtype=object)

# %%
mpg.drv.unique()
# Out:
# array(['f', '4', 'r'], dtype=object)

# %% [markdown]
# ##함수와 메서드 차이 알아복;

# %% [markdown]
# *내장함수

# %%
sum([4,7,8])
# Out:
# 19

# %%
max([3,8,5,1,14,2])
# Out:
# 14

# %%
min([3,5,7,1,87,4])
# Out:
# 1

# %% [markdown]
# *메소드

# %%
df = pd.DataFrame([3,5,6,78,21])
df.head()
# Out:
#     0
# 0   3
# 1   5
# 2   6
# 3  78
# 4  21

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       5 non-null      int64
# dtypes: int64(1)
# memory usage: 168.0 bytes

# %% [markdown]
# * 패키지 함수

# %% [markdown]
# 함수와 메소드 차이알아보기
# * ?

# %%
import pandas as pd
pd.read_csv('exam.csv')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# #05-2 변수명 바꾸기(p113):시험예상

# %%
df_raw = pd.DataFrame({'var1' : [1,2,3],
                       'var2' : [2,3,2],
                       'var3' : [10,20,30]})
df_raw
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     3     2    30

# %%
df_new = df_raw

# %%
df_new
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     3     2    30

# %%
df_new.rename(columns= {'var2' : 'v2'})
# Out:
#    var1  v2  var3
# 0     1   2    10
# 1     2   3    20
# 2     3   2    30

# %%
df_new = df_new.rename(columns= {'var2' : 'v2'})
df_new
# Out:
#    var1  v2  var3
# 0     1   2    10
# 1     2   3    20
# 2     3   2    30

# %%
df_raw
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     3     2    30

# %%
df_new = df_new.rename(index= {0: 'x', 1: 'y', 2: 'z'})
df_new
# Out:
#    var1  v2  var3
# x     1   2    10
# y     2   3    20
# z     3   2    30

# %%
df_raw.rename?

# %%
df = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6]})
df.rename(columns={"A": "a", "B": "c"})
# Out:
#    a  c
# 0  1  4
# 1  2  5
# 2  3  6

# %% [markdown]
# ### 05-3 파생변수 망들기

# %%
df = pd.DataFrame({'var1' : [4,3,8],
                   'var2' : [2,6,1]})
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1 =df
df1
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1['var_sum'] = df['var1'] + df['var2']
df1
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
#열 var mean <- var1과 vaewrd2의 펵윰ㄱㄴ
df1['var_mean'] =( df['var1'] + df['var2']) / 2
df1
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %%
df2 = df.copy()
df2
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df2.sum(axis=1)
# Out:
# 0    6
# 1    9
# 2    9
# dtype: int64

# %%
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
# 새로운 열 ㅍㅁㄱㄹ.ㅡㄷㅇ펵윤a

# %% [markdown]
# #mpg 통합 연비 변수 ㅁ나드릭

# %%
# mpg 데이터 부럴오기
mpg = pd.read_csv("mpg.csv")

# %%
#통합 연비 변수 ㅣㅁㄴㄷ,ㄹㄱ;,
mpg['total'] = (mpg['cty'] + mpg['hwy']) / 2
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total
# 0   23.5
# 1   25.0
# 2   25.5
# 3   25.5
# 4   21.0

# %%
1
# Out:
# 1

# %%
sum(mpg['total']) / len(mpg)
# Out:
# 20.14957264957265

# %%
mpg['total'].mean()
# Out:
# 20.14957264957265

# %% [markdown]
# ## 조건문을 활용햐ㅐ 파새엽ㄴ수 만들기

# %%
mpg['total'].describe()
# Out:
# count    234.000000
# mean      20.149573
# std        5.050290
# min       10.500000
# 25%       15.500000
# 50%       20.500000
# 75%       23.500000
# max       39.500000
# Name: total, dtype: float64

# %%
#도수분포표 만들기
mpg['total'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
import seaborn as sns
sns.histplot(mpg, x="total");

# %% [markdown]
# ###합격변수 판정정 만드릭 p120

# %%
import numpy as np

#25 이상이면 pass, 그렇지 않으면 fail부여
mpg['test'] = np.where(mpg['total'] >= 25, 'pass', 'fail')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  test
# 0   23.5  fail
# 1   25.0  pass
# 2   25.5  pass
# 3   25.5  pass
# 4   21.0  fail

# %%
mpg['test'].value_counts()
# Out:
# fail    191
# pass     43
# Name: test, dtype: int64

# %%
couunt_test = mpg['test'].value_counts()
couunt_test.plot.bar();

# %%
couunt_test.plot.bar(rot = 0);

# %%
sns.countplot(mpg, x='test', hue='test', stat= 'percent'); #시험예상
